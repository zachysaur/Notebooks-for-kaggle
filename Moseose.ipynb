# %%
# %cd /kaggle/working
# !git clone -b dev https://github.com/camenduru/MusePose
# %cd /kaggle/working/MusePose

# !pip install -q torch==2.1.0+cu121 torchvision==0.16.0+cu121 torchaudio==2.1.0+cu121 torchtext==0.16.0 torchdata==0.7.0 --extra-index-url https://download.pytorch.org/whl/cu121
# !pip install -q https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl
# !pip install -q https://github.com/camenduru/wheels/releases/download/colab/mmcv-2.0.1-cp310-cp310-linux_x86_64.whl
# !pip install -q moviepy av diffusers==0.24.0 einops omegaconf transformers==4.33.1 accelerate==0.29.3 mmdet mmpose

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/resolve/main/MusePose/denoising_unet.pth -d /kaggle/working/MusePose/pretrained_weights/MusePose -o denoising_unet.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/resolve/main/MusePose/motion_module.pth -d /kaggle/working/MusePose/pretrained_weights/MusePose -o motion_module.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/resolve/main/MusePose/pose_guider.pth -d /kaggle/working/MusePose/pretrained_weights/MusePose -o pose_guider.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/resolve/main/MusePose/reference_unet.pth -d /kaggle/working/MusePose/pretrained_weights/MusePose -o reference_unet.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/resolve/main/dwpose/dw-ll_ucoco_384.pth -d /kaggle/working/MusePose/pretrained_weights/dwpose -o dw-ll_ucoco_384.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/resolve/main/dwpose/yolox_l_8x8_300e_coco.pth -d /kaggle/working/MusePose/pretrained_weights/dwpose -o yolox_l_8x8_300e_coco.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/resolve/main/image_encoder/pytorch_model.bin -d /kaggle/working/MusePose/pretrained_weights/image_encoder -o pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/raw/main/image_encoder/config.json -d /kaggle/working/MusePose/pretrained_weights/image_encoder -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/resolve/main/sd-image-variations-diffusers/diffusion_pytorch_model.bin -d /kaggle/working/MusePose/pretrained_weights/sd-image-variations-diffusers/unet -o diffusion_pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/raw/main/sd-image-variations-diffusers/config.json -d /kaggle/working/MusePose/pretrained_weights/sd-image-variations-diffusers/unet -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/resolve/main/sd-vae-ft-mse/diffusion_pytorch_model.bin -d /kaggle/working/MusePose/pretrained_weights/sd-vae-ft-mse -o diffusion_pytorch_model.bin
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/MusePose/raw/main/sd-vae-ft-mse/config.json -d /kaggle/working/MusePose/pretrained_weights/sd-vae-ft-mse -o config.json

# %%
# Uninstall existing versions of mmcv, mmcv-full, and mmcv-lite
# !pip uninstall -y mmcv mmcv-full mmcv-lite

# Install the required version of mmcv-full
# !pip install mmcv-full==2.3.0

# Install mmpose and mmdet using mim
# !pip install openmim
# !mim install 'mmpose>=1.1.0'
# !mim install 'mmdet>=3.1.0'

# Verify the versions to ensure compatibility
import mmcv
import mmpose

print(f"mmcv version: {mmcv.__version__}")
print(f"mmpose version: {mmpose.__version__}")

# %%
# Install necessary dependencies
# !apt-get update
# !apt-get install -y libgtk2.0-dev pkg-config

# Rebuild OpenCV (this command is just illustrative; actual commands may vary)
# !pip uninstall -y opencv-python
# !pip install opencv-python-headless

# %%
# !pip install opencv-python

# %% [markdown]
# # Replace Files

# %%
import shutil

# Define the source and destination paths for the video file
source_video = '/kaggle/input/filetoreplace/dance.mp4'
destination_video = '/kaggle/working/MusePose/assets/videos/dance.mp4'

# Define the source and destination paths for the image file
source_image = '/kaggle/input/filetoreplace/ref.png'
destination_image = '/kaggle/working/MusePose/assets/images/ref.png'

# Copy the video file
shutil.copyfile(source_video, destination_video)

# Copy the image file
shutil.copyfile(source_image, destination_image)

print("Files replaced successfully!")

# %%
# !python pose_align.py --imgfn_refer ./assets/images/ref.png --vidfn ./assets/videos/dance.mp4

# %%
# !python test_stage_2.py --config ./configs/test_stage_2.yaml -W 448 -H 448
